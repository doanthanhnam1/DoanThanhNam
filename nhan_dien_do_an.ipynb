# %% [markdown]
# <a href="https://colab.research.google.com/github/doanthanhnam1/DoanThanhNam/blob/main/nhan_dien_do_an.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import listdir
from numpy import asarray
from numpy import save
from keras import preprocessing
from tensorflow.keras.utils import load_img, img_to_array

# %%
data="/content/drive/MyDrive/do_an/do_an/"

# %%
print("Bắt đầu xử lý ảnh...")

pixels,labels=list(),list()

for folder in listdir(data):
    if folder!='.DS_Store':
        #print("Folder=",folder)
        for file in listdir(data  + folder):
            if file!='.DS_Store':
                #print("File=", file)
                pixel=load_img(data  + folder +"/" + file,target_size=(200,200))
                pixel=img_to_array(pixel)
                pixels.append(pixel)
                labels.append( folder)

pixels =asarray(pixels)
labels =asarray(labels)#.reshape(-1,1)
# Out:
# Bắt đầu xử lý ảnh...

# %%
from sklearn.preprocessing import LabelBinarizer
import pickle
from sklearn.model_selection import train_test_split
encoder = LabelBinarizer()
labels = encoder.fit_transform(labels)
#print(labels)

file = open('pix.data', 'wb')
# dump information to that file
pickle.dump((pixels,labels), file)
# close the file
file.close()

# %%
def load_data():
    file = open('pix.data', 'rb')
    # dump information to that file
    (pixels, labels) = pickle.load(file)
    # close the file
    file.close()
    return pixels, labels

#save_data()
X,y = load_data()
#random.shuffle(X)
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=100)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (245, 200, 200, 3)
# (62, 200, 200, 3)

# %%
from keras.models import Sequential
from keras.layers import Dense
from numpy.ma.core import reshape

# %%
X_train= X_train.astype('float32')/255
print(y_train.shape)
X_test= X_test.astype('float32')/255
# Out:
# (245, 10)

# %%
from keras import models 
from keras.models import Sequential,Model
from keras import Input
from keras.layers import Dense,Flatten,Dropout,Conv2D,MaxPooling2D,Normalization
from keras.optimizers import Adam
batch_size=100 #lô
epochs=20     #số lần học
classes=10    #phân loại

# %%
model=Sequential()
model.add(Conv2D(32,kernel_size=(3,3),activation='linear',input_shape=(200,200,3),padding='same'))
from keras.layers import LeakyReLU
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D((2,2),padding='same'))
#so lan tich chap
model.add(Conv2D(64,(3,3),activation='linear',padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D((2,2),padding='same'))

# %%
model.add(Conv2D(128,(3,3),activation='linear',padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D((2,2),padding='same'))

# %%
from keras import optimizers
from keras import losses
model.add(Flatten())
model.add(Dense(1000,activation='linear'))
model.add(Dense(500,activation='linear'))
model.add(LeakyReLU(alpha=0.1))
model.add(Dense(classes,activation='softmax'))
model.compile(loss=losses.categorical_crossentropy,optimizer=Adam(),metrics=['accuracy'])
model.summary()
train=model.fit(X_train,y_train,batch_size=batch_size,epochs=epochs,verbose=1)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_21 (Conv2D)          (None, 200, 200, 32)      896
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 200, 200, 32)      0
#
#  max_pooling2d_17 (MaxPoolin  (None, 100, 100, 32)     0
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 100, 100, 64)      18496
#
#  leaky_re_lu_15 (LeakyReLU)  (None, 100, 100, 64)      0
#
#  max_pooling2d_18 (MaxPoolin  (None, 50, 50, 64)       0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 50, 50, 128)       73856
#
#  leaky_re_lu_16 (LeakyReLU)  (None, 50, 50, 128)       0
#
#  max_pooling2d_19 (MaxPoolin  (None, 25, 25, 128)      0
#  g2D)
#
#  flatten_6 (Flatten)         (None, 80000)             0
#
#  dense_18 (Dense)            (None, 1000)              80001000
#
#  dense_19 (Dense)            (None, 500)               500500
#
#  leaky_re_lu_17 (LeakyReLU)  (None, 500)               0
#
#  dense_20 (Dense)            (None, 10)                5010
#
# =================================================================
# Total params: 80,599,758
# Trainable params: 80,599,758
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 3/3 [==============================] - 6s 811ms/step - loss: 18.7738 - accuracy: 0.1796
# Epoch 2/20
# 3/3 [==============================] - 0s 139ms/step - loss: 6.5633 - accuracy: 0.1306
# Epoch 3/20
# 3/3 [==============================] - 0s 144ms/step - loss: 2.8497 - accuracy: 0.1102
# Epoch 4/20
# 3/3 [==============================] - 0s 146ms/step - loss: 2.3049 - accuracy: 0.1959
# Epoch 5/20
# 3/3 [==============================] - 0s 144ms/step - loss: 2.0548 - accuracy: 0.2571
# Epoch 6/20
# 3/3 [==============================] - 0s 143ms/step - loss: 1.8581 - accuracy: 0.3551
# Epoch 7/20
# 3/3 [==============================] - 0s 140ms/step - loss: 1.7080 - accuracy: 0.4898
# Epoch 8/20
# 3/3 [==============================] - 0s 158ms/step - loss: 1.4236 - accuracy: 0.5020
# Epoch 9/20
# 3/3 [==============================] - 0s 146ms/step - loss: 1.2326 - accuracy: 0.6408
# Epoch 10/20
# 3/3 [==============================] - 0s 139ms/step - loss: 1.0375 - accuracy: 0.6408
# Epoch 11/20
# 3/3 [==============================] - 0s 134ms/step - loss: 0.9570 - accuracy: 0.6531
# Epoch 12/20
# 3/3 [==============================] - 0s 135ms/step - loss: 0.6536 - accuracy: 0.8122
# Epoch 13/20
# 3/3 [==============================] - 0s 133ms/step - loss: 0.5026 - accuracy: 0.8612
# Epoch 14/20
# 3/3 [==============================] - 0s 132ms/step - loss: 0.3661 - accuracy: 0.8857
# Epoch 15/20
# 3/3 [==============================] - 0s 133ms/step - loss: 0.2916 - accuracy: 0.9388
# Epoch 16/20
# 3/3 [==============================] - 0s 133ms/step - loss: 0.1551 - accuracy: 0.9714
# Epoch 17/20
# 3/3 [==============================] - 0s 132ms/step - loss: 0.1194 - accuracy: 0.9837
# Epoch 18/20
# 3/3 [==============================] - 0s 132ms/step - loss: 0.0680 - accuracy: 0.9959
# Epoch 19/20
# 3/3 [==============================] - 0s 133ms/step - loss: 0.0476 - accuracy: 0.9959
# Epoch 20/20
# 3/3 [==============================] - 0s 129ms/step - loss: 0.0272 - accuracy: 1.0000

# %%
model.save("/content/drive/MyDrive/Colab Notebooks/BT/nhan_dien_do_an.h5")

# %%
from keras.saving.saving_lib import load_model
import matplotlib.pyplot as plt
from keras.models import load_model
model100=load_model("/content/drive/MyDrive/Colab Notebooks/BT/nhan_dien_do_an.h5")
img=load_img('/content/drive/MyDrive/AI/test2/anh.jpg')
plt.imshow(img)
plt.show()

# %%
img = load_img('/content/drive/MyDrive/AI/test2/anh.jpg',target_size=(200,200))
plt.imshow(img)

# %%
import numpy as np
class_name = ['Bánh Mì','Bánh ướt','Bánh xèo','Bún bò huế','Bún thịt nướng','Chả giò','Cơm tấm','Mì quảng','phở','xôi']
img=img_to_array(img)
img=img.reshape(1,200,200,3)
img=img.astype('float32')
img=img/255
predict = model100.predict(img)
print("This picture is: ", class_name[np.argmax(predict[0])], (predict[0]))
print(np.max(predict[0],axis=0))
# Out:
# 1/1 [==============================] - 1s 772ms/step
# This picture is:  Mì quảng [2.0876450e-05 9.4234718e-05 3.2511271e-06 2.3992825e-04 6.2384563e-05
#  2.1533010e-04 4.1325742e-04 9.9776626e-01 2.9134052e-04 8.9321507e-04]
# 0.99776626
