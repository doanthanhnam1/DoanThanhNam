# %% [markdown]
# <a href="https://colab.research.google.com/github/doanthanhnam1/DoanThanhNam/blob/main/VNd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import listdir
from numpy import asarray
from numpy import save
from keras import preprocessing
from tensorflow.keras.utils import load_img, img_to_array

# %%
tien_folder = "/content/drive/MyDrive/tien/"

# %%
print("Bắt đầu xử lý ảnh...")

pixels,labels=list(),list()

for folder in listdir(tien_folder):
    if folder!='.DS_Store':
        #print("Folder=",folder)
        for file in listdir(tien_folder  + folder):
            if file!='.DS_Store':
                #print("File=", file)
                pixel=load_img(tien_folder  + folder +"/" + file)
                pixel=img_to_array(pixel)
                pixels.append(pixel)
                labels.append( folder)

pixels =asarray(pixels)
labels =asarray(labels)#.reshape(-1,1)
# Out:
# Bắt đầu xử lý ảnh...

# %%
#save('tien.npy',pixels)
#save('tien.npy',labels)

# %%
from sklearn.preprocessing import LabelBinarizer
import pickle
from sklearn.model_selection import train_test_split
encoder = LabelBinarizer()
labels = encoder.fit_transform(labels)
#print(labels)

file = open('pix.data', 'wb')
# dump information to that file
pickle.dump((pixels,labels), file)
# close the file
file.close()

# %%
def load_data():
    file = open('pix.data', 'rb')
    # dump information to that file
    (pixels, labels) = pickle.load(file)
    # close the file
    file.close()
    return pixels, labels

#save_data()
X,y = load_data()
#random.shuffle(X)
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=100)

print(X_train.shape)
print(X_test.shape)
# Out:
# (6725, 144, 192, 3)
# (1682, 144, 192, 3)

# %%
from keras.models import Sequential
from keras.layers import Dense
from numpy.ma.core import reshape

X_train = X_train.reshape(6725,144,192,3)
X_test= X_test.reshape(1682,144,192,3)

# %%
X_train= X_train.astype('float32')/255
print(y_train.shape)
X_test= X_test.astype('float32')/255

#from keras.utils import to_categorical 
#y_train= to_categorical(y_train,10)
#print(y_train.shape)
#y_test= to_categorical(y_test,10)
# Out:
# (328, 10)

# %%
from keras import models 
from keras.models import Sequential,Model
from keras import Input
from keras.layers import Dense,Flatten,Dropout,Conv2D,MaxPooling2D,Normalization
from keras.optimizers import Adam
batch_size=64 #lô
epochs=20     #số lần học
classes=10    #phân loại

# %%
model=Sequential()
model.add(Conv2D(32,kernel_size=(3,3),activation='linear',input_shape=(144,192,3),padding='same'))
from keras.layers import LeakyReLU
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D((2,2),padding='same'))
#so lan tich chap
model.add(Conv2D(64,(3,3),activation='linear',padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D((2,2),padding='same'))

# %%
model.add(Conv2D(128,(3,3),activation='linear',padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D((2,2),padding='same'))

# %%
from keras import optimizers
from keras import losses
model.add(Flatten())
model.add(Dense(128,activation='linear'))
model.add(LeakyReLU(alpha=0.1))
model.add(Dense(classes,activation='softmax'))
model.compile(loss=losses.categorical_crossentropy,optimizer=Adam(),metrics=['accuracy'])
model.summary()
train=model.fit(X_train,y_train,batch_size=batch_size,epochs=epochs,verbose=1)
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_41 (Conv2D)          (None, 128, 128, 32)      896
#
#  leaky_re_lu_52 (LeakyReLU)  (None, 128, 128, 32)      0
#
#  max_pooling2d_39 (MaxPoolin  (None, 64, 64, 32)       0
#  g2D)
#
#  conv2d_42 (Conv2D)          (None, 64, 64, 64)        18496
#
#  leaky_re_lu_53 (LeakyReLU)  (None, 64, 64, 64)        0
#
#  max_pooling2d_40 (MaxPoolin  (None, 32, 32, 64)       0
#  g2D)
#
#  conv2d_43 (Conv2D)          (None, 32, 32, 128)       73856
#
#  leaky_re_lu_54 (LeakyReLU)  (None, 32, 32, 128)       0
#
#  max_pooling2d_41 (MaxPoolin  (None, 16, 16, 128)      0
#  g2D)
#
#  flatten_13 (Flatten)        (None, 32768)             0
#
#  dense_34 (Dense)            (None, 128)               4194432
#
#  leaky_re_lu_55 (LeakyReLU)  (None, 128)               0
#
#  dense_35 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 4,288,970
# Trainable params: 4,288,970
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 6/6 [==============================] - 1s 47ms/step - loss: 2.6712 - accuracy: 0.0945
# Epoch 2/20
# 6/6 [==============================] - 0s 36ms/step - loss: 2.3250 - accuracy: 0.1616
# Epoch 3/20
# 6/6 [==============================] - 0s 34ms/step - loss: 2.2713 - accuracy: 0.1860
# Epoch 4/20
# 6/6 [==============================] - 0s 34ms/step - loss: 2.1339 - accuracy: 0.4238
# Epoch 5/20
# 6/6 [==============================] - 0s 36ms/step - loss: 1.8368 - accuracy: 0.4268
# Epoch 6/20
# 6/6 [==============================] - 0s 39ms/step - loss: 1.4945 - accuracy: 0.5213
# Epoch 7/20
# 6/6 [==============================] - 0s 36ms/step - loss: 1.1928 - accuracy: 0.5823
# Epoch 8/20
# 6/6 [==============================] - 0s 33ms/step - loss: 0.7763 - accuracy: 0.7744
# Epoch 9/20
# 6/6 [==============================] - 0s 35ms/step - loss: 0.4541 - accuracy: 0.8780
# Epoch 10/20
# 6/6 [==============================] - 0s 33ms/step - loss: 0.3069 - accuracy: 0.9024
# Epoch 11/20
# 6/6 [==============================] - 0s 34ms/step - loss: 0.1821 - accuracy: 0.9482
# Epoch 12/20
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0979 - accuracy: 0.9726
# Epoch 13/20
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0816 - accuracy: 0.9726
# Epoch 14/20
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0644 - accuracy: 0.9817
# Epoch 15/20
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0538 - accuracy: 0.9848
# Epoch 16/20
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0622 - accuracy: 0.9817
# Epoch 17/20
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0985 - accuracy: 0.9604
# Epoch 18/20
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0936 - accuracy: 0.9726
# Epoch 19/20
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0561 - accuracy: 0.9787
# Epoch 20/20
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0210 - accuracy: 0.9970

# %%
model.save("/content/drive/MyDrive/Colab Notebooks/BT/nhan_dien_tien.h5")

# %%
from keras.saving.saving_lib import load_model
import matplotlib.pyplot as plt
from keras.models import load_model
model100=load_model("/content/drive/MyDrive/Colab Notebooks/BT/nhan_dien_tien.h5")
img=load_img('/content/drive/MyDrive/tien/50000/61.png')
plt.imshow(img)
plt.show()

# %%
img = load_img('/content/drive/MyDrive/tien/50000/61.png',target_size=(144,192))
plt.imshow(img)

# %%
import numpy as np
class_name = ['00000','1000','2000','5000','10000','20000','50000','100000','200000','500000']
img=img_to_array(img)
img=img.reshape(1,144,192,3)
img=img.astype('float32')
img=img/255
predict = model100.predict(img)
print("This picture is: ", class_name[np.argmax(predict[0])], (predict[0]))
print(np.max(predict[0],axis=0))
# Out:
# WARNING:tensorflow:5 out of the last 10 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f5793af0ee0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 69ms/step
# This picture is:  200000 [8.5390639e-08 6.1699916e-02 2.9612340e-07 1.9380718e-04 8.2389661e-04
#  3.9666073e-05 5.3486161e-08 4.5560392e-10 9.3724227e-01 2.2293306e-10]
# 0.93724227
