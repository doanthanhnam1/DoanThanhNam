# %% [markdown]
# <a href="https://colab.research.google.com/github/doanthanhnam1/DoanThanhNam/blob/main/week10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from keras import models  
from keras.models import load_model
model100=load_model('/content/drive/MyDrive/Colab Notebooks/BT/cifar100.h5')

# %%
import matplotlib.pyplot as plt
from keras.utils import load_img, img_to_array

# %%
img=load_img('/content/drive/MyDrive/New/IMG_20230327_053531.jpg')
plt.imshow(img)
plt.show()

# %%
img = load_img('/content/drive/MyDrive/New/IMG_20230327_053531.jpg',target_size=(32,32))
plt.imshow(img)

# %%
import numpy as np
img=img_to_array(img)
img=img.reshape(1,32*32*3)
img=img.astype('float32')
img=img/255
np.argmax(model100.predict(img),axis=-1)
# Out:
# 1/1 [==============================] - 0s 67ms/step
# array([61])

# %%
'''
img1 = load_img('/content/drive/MyDrive/New/IMG_20230327_053531.jpg',target_size=(32,32))
img1=img_to_array(img1)
img1=img1.reshape(1,32*32*3)
img1=img1.astype('float32')/255

img2 = load_img('/content/drive/MyDrive/New/IMG_20230327_053104.jpg',target_size=(32,32))
img2=img_to_array(img2)
img2=img2.reshape(1,32*32*3)
img2=img2.astype('float32')/255

img3 = load_img('/content/drive/MyDrive/New/IMG_20230327_053106.jpg',target_size=(32,32))
img3=img_to_array(img3)
img3=img3.reshape(1,32*32*3)
img3=img3.astype('float32')/255

img4 = load_img('/content/drive/MyDrive/New/IMG_20230327_053109.jpg',target_size=(32,32))
img4=img_to_array(img4)
img4=img4.reshape(1,32*32*3)
img4=img4.astype('float32')/255

img5 = load_img('/content/drive/MyDrive/New/IMG_20230327_053111.jpg',target_size=(32,32))
img5=img_to_array(img5)
img5=img5.reshape(1,32*32*3)
img5=img5.astype('float32')/255

img6 = load_img('/content/drive/MyDrive/New/IMG_20230327_053124.jpg',target_size=(32,32))
img6=img_to_array(img6)
img6=img6.reshape(1,32*32*3)
img6=img6.astype('float32')/255

train=[img1,img2,img3,img4,img5,img6]
for i in range(6):
  plt.subplot(5,5,i+1)
  plt.tight_layout()
  plt.imshow(train[i], cmap = 'gray', interpolation = 'none')
  plt.xticks([])
  plt.yticks([])
  '''

# %%
from matplotlib.image import imread
folder='/content/drive/MyDrive/New/'
for i in range(20):
  plt.subplot(5,5,i+1)
  filename=folder+'A' + str(i)+ '.jpg'
  img=imread(filename)
  plt.imshow(img)
plt.show()
