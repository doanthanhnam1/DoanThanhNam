# %% [markdown]
# <a href="https://colab.research.google.com/github/doanthanhnam1/DoanThanhNam/blob/main/nhan_dien_tien.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import listdir
from numpy import asarray
from numpy import save
from keras import preprocessing
from tensorflow.keras.utils import load_img, img_to_array

# %%
tien_folder = "/content/drive/MyDrive/tien/"

# %%
dest_size = (128, 128)
print("Bắt đầu xử lý ảnh...")

pixels,labels=list(),list()

for folder in listdir(tien_folder):
    if folder!='.DS_Store':
        #print("Folder=",folder)
        for file in listdir(tien_folder  + folder):
            if file!='.DS_Store':
                #print("File=", file)
                pixel=load_img(tien_folder  + folder +"/" + file,target_size=(128,128))
                pixel=img_to_array(pixel)
                pixels.append(pixel)
                labels.append( folder)

pixels =asarray(pixels)
labels =asarray(labels)#.reshape(-1,1)
# Out:
# Bắt đầu xử lý ảnh...

# %%
save('tien.npy',pixels)
save('tien.npy',labels)

# %%
from sklearn.preprocessing import LabelBinarizer
import pickle
from sklearn.model_selection import train_test_split
encoder = LabelBinarizer()
labels = encoder.fit_transform(labels)
#print(labels)

file = open('pix.data', 'wb')
# dump information to that file
pickle.dump((pixels,labels), file)
# close the file
file.close()

# %%
def load_data():
    file = open('pix.data', 'rb')
    # dump information to that file
    (pixels, labels) = pickle.load(file)
    # close the file
    file.close()
    return pixels, labels

#save_data()
X,y = load_data()
#random.shuffle(X)
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=100)

print(X_train.shape)
print(X_test.shape)
# Out:
# (328, 128, 128, 3)
# (82, 128, 128, 3)

# %%
from keras.models import Sequential
from keras.layers import Dense
from numpy.ma.core import reshape

X_train = X_train.reshape(328,128,128,3)
X_test= X_test.reshape(82,128,128,3)

# %%
X_train= X_train.astype('float32')/255
print(y_train.shape)
X_test= X_test.astype('float32')/255

#from keras.utils import to_categorical 
#y_train= to_categorical(y_train,10)
#print(y_train.shape)
#y_test= to_categorical(y_test,10)
# Out:
# (328, 10)

# %%
from keras import models 
from keras.models import Sequential,Model
from keras import Input
from keras.layers import Dense,Flatten,Dropout,Conv2D,MaxPooling2D,Normalization
from keras.optimizers import Adam
batch_size=64 #lô
epochs=20     #số lần học
classes=10    #phân loại

# %%
model=Sequential()
model.add(Conv2D(32,kernel_size=(3,3),activation='linear',input_shape=(128,128,3),padding='same'))
from keras.layers import LeakyReLU
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D((2,2),padding='same'))
#so lan tich chap
model.add(Conv2D(64,(3,3),activation='linear',padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D((2,2),padding='same'))

# %%
model.add(Conv2D(128,(3,3),activation='linear',padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D((2,2),padding='same'))

# %%
from keras import optimizers
from keras import losses
model.add(Flatten())
model.add(Dense(128,activation='linear'))
model.add(LeakyReLU(alpha=0.1))
model.add(Dense(classes,activation='softmax'))
model.compile(loss=losses.categorical_crossentropy,optimizer=Adam(),metrics=['accuracy'])
model.summary()
train=model.fit(X_train,y_train,batch_size=batch_size,epochs=epochs,verbose=1)
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_29 (Conv2D)          (None, 128, 128, 32)      896
#
#  leaky_re_lu_36 (LeakyReLU)  (None, 128, 128, 32)      0
#
#  max_pooling2d_27 (MaxPoolin  (None, 64, 64, 32)       0
#  g2D)
#
#  conv2d_30 (Conv2D)          (None, 64, 64, 64)        18496
#
#  leaky_re_lu_37 (LeakyReLU)  (None, 64, 64, 64)        0
#
#  max_pooling2d_28 (MaxPoolin  (None, 32, 32, 64)       0
#  g2D)
#
#  conv2d_31 (Conv2D)          (None, 32, 32, 128)       73856
#
#  leaky_re_lu_38 (LeakyReLU)  (None, 32, 32, 128)       0
#
#  max_pooling2d_29 (MaxPoolin  (None, 16, 16, 128)      0
#  g2D)
#
#  flatten_9 (Flatten)         (None, 32768)             0
#
#  dense_26 (Dense)            (None, 128)               4194432
#
#  leaky_re_lu_39 (LeakyReLU)  (None, 128)               0
#
#  dense_27 (Dense)            (None, 10)                1290
#
# ...

# %%
model.save("/content/drive/MyDrive/Colab Notebooks/BT/nhan_dien_tien.h5")

# %%
from keras.saving.saving_lib import load_model
import matplotlib.pyplot as plt
from keras.models import load_model
model100=load_model("/content/drive/MyDrive/Colab Notebooks/BT/nhan_dien_tien.h5")
img=load_img('/content/drive/MyDrive/AI/tải xuống.jpg')
plt.imshow(img)
plt.show()

# %%
img = load_img('/content/drive/MyDrive/AI/tải xuống.jpg',target_size=(128,128))
plt.imshow(img)

# %%
import numpy as np
class_name = ['00000','1000','2000','5000','10000','20000','50000','100000','200000','500000']
img=img_to_array(img)
img=img.reshape(1,128,128,3)
img=img.astype('float32')
img=img/255
predict = model100.predict(img)
print("This picture is: ", class_name[np.argmax(predict[0])], (predict[0]))
print(np.max(predict[0],axis=0))
# Out:
# 1/1 [==============================] - 0s 21ms/step
# This picture is:  100000 [2.0278771e-13 1.4943336e-05 2.8709363e-02 3.5494133e-03 2.0435199e-02
#  3.7896821e-01 3.8365382e-05 5.6823033e-01 4.1046140e-05 1.3151855e-05]
# 0.56823033
